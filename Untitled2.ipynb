# %%
import pandas as pd


mod_i_df = pd.read_excel('IPROD.xlsx')

second_df = pd.read_excel('IPHOTO.xlsx')



mod_ii_df = pd.merge(mod_i_df,second_df[['MFGPART','DEF_PHOTO']], on='MFGPART', how='left')


# mod_iii_df = pd.merge(mod_ii_df,third_df[['CONTNUM','GSAPRICE','MLP']], on='CONTNUM', how='left')\

# mod_iii_df
# Out:
#          CONTNUM       MFGPART             MFGNAME  \
# 0   GS-02F-0180V  000-40780-01  KLINGE CORPORATION
# 1   GS-02F-0180V  000-41080-01  KLINGE CORPORATION
# 2   GS-02F-0180V  000-51080-01  KLINGE CORPORATION
# 3   GS-02F-0180V  000-52080-01  KLINGE CORPORATION
# 4   GS-02F-0180V     000-42086  KLINGE CORPORATION
# 5   GS-02F-0180V  000-42086-02  KLINGE CORPORATION
# 6   GS-02F-0180V     000-52086  KLINGE CORPORATION
# 7   GS-02F-0180V     000-42096  KLINGE CORPORATION
# 8   GS-02F-0180V     000-52096  KLINGE CORPORATION
# 9   GS-02F-0180V     000-54086  KLINGE CORPORATION
# 10  GS-02F-0180V     000-44096  KLINGE CORPORATION
# 11  GS-02F-0180V  000-44096-02  KLINGE CORPORATION
# 12  GS-02F-0180V     000-54096  KLINGE CORPORATION
# 13  GS-02F-0180V     000-10000  KLINGE CORPORATION
# 14  GS-02F-0180V   000-FSB-770  KLINGE CORPORATION
#
#                                     PRODNAME      VENDPART  \
# 0     TRICON MIL SPEC. REFRGERATED CONTAINER  000-40780-01
# ...
