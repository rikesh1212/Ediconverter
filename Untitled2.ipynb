# %%
import pandas as pd


mod_i_df = pd.read_excel('IPROD.xlsx')

second_df = pd.read_excel('IPHOTO.xlsx')

mod_ii_df = pd.merge(mod_i_df,second_df[['CONTNUM','DEF_PHOTO']], on='CONTNUM', how='left')

mod_ii_df
# Out:
#           CONTNUM       MFGPART             MFGNAME  \
# 0    GS-02F-0180V  000-40780-01  KLINGE CORPORATION
# 1    GS-02F-0180V  000-40780-01  KLINGE CORPORATION
# 2    GS-02F-0180V  000-40780-01  KLINGE CORPORATION
# 3    GS-02F-0180V  000-40780-01  KLINGE CORPORATION
# 4    GS-02F-0180V  000-40780-01  KLINGE CORPORATION
# ..            ...           ...                 ...
# 220  GS-02F-0180V   000-FSB-770  KLINGE CORPORATION
# 221  GS-02F-0180V   000-FSB-770  KLINGE CORPORATION
# 222  GS-02F-0180V   000-FSB-770  KLINGE CORPORATION
# 223  GS-02F-0180V   000-FSB-770  KLINGE CORPORATION
# 224  GS-02F-0180V   000-FSB-770  KLINGE CORPORATION
#
#                                    PRODNAME      VENDPART  \
# 0    TRICON MIL SPEC. REFRGERATED CONTAINER  000-40780-01
# 1    TRICON MIL SPEC. REFRGERATED CONTAINER  000-40780-01
# 2    TRICON MIL SPEC. REFRGERATED CONTAINER  000-40780-01
# 3    TRICON MIL SPEC. REFRGERATED CONTAINER  000-40780-01
# ...
